# %% [markdown]
# ## Imports

# %%
# utils
import concurrent.futures
import os
import sys
from functools import partial
from pathlib import Path

from tqdm import tqdm

PROJECT_DIR = Path.cwd().parent
sys.path.append(str(PROJECT_DIR))

# basics
import numpy as np
import pandas as pd

# metrics
from src.claire import CLAIRE
from utils import config
from utils.reader import read_file_yaml

np.random.seed(0)
# Out:
# 2023-07-28 15:57:49.013904: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-28 15:57:49.488825: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
path_root = PROJECT_DIR / "data"
path_conf = PROJECT_DIR / "conf"
file_path_parameters = path_conf / "parameters.yml"
path_data = [path_root / i for i in config.file_names]

parameters = read_file_yaml(file_path_parameters)

ext_type = parameters["outputs"]["extension_type"]
ext_local_img = parameters["outputs"]["extension_local_img"]
ext_best_img = parameters["outputs"]["extension_best_img"]

# %%
under_line = "\n{}\n"
title_part_n2 = "PROJECT_DIR: [ {} ]".format(PROJECT_DIR)
title_part_n3 = under_line.format("".join(["-"] * len(title_part_n2)))
title_part_n1 = under_line.format("".join(["-"] * len(title_part_n2)))
print(title_part_n1 + title_part_n2 + title_part_n3)
# Out:
# -------------------------------------------------------------
# PROJECT_DIR: [ /home/manuel/projects/aaai-claire-clustering ]
# -------------------------------------------------------------

# %% [markdown]
# ## Read

# %%
data_all = {i: pd.read_csv(path_data[idx] / Path(i + ext_type)) for idx, i in enumerate(config.file_names)}

# %% [markdown]
# ## Methods

# %%
def process_file(k_random, path_result_k_random, _X, _Y, config, data_random, parameters, i):
    models_params = config.params | {"optics": [config._optics_params[i]]}

    claire = CLAIRE(
        models_name=np.unique(config.models_name_dataset[i]),
        models=config.models,
        params=models_params,
        _X=_X,
        _Y=_Y,
        metrics=config.metrics,
        dir_result=path_result_k_random,
        path_root=PROJECT_DIR,
    )

    if len(np.unique(_Y[i])) == 1:
        n_clusters = np.random.randint(1, 10)
    else:
        n_clusters = len(np.unique(_Y[i]))

    which_k_dataset = "dataset: [ {} ]".format(i)
    print(title_part_n1 + which_k_dataset + title_part_n3)

    #  processing
    combination_models = claire.transform()
    claire.fit_combination_models(combination_models, _X[i])
    data_results = claire.generate_results(combination_models)

    # add random columns
    data_results = pd.concat([data_results, data_random[i].iloc[:, :(k_random + 1)]], axis=1)
    pij = claire.generate_pij_matrix(data_results, k_random + 1, n_clusters)

    # set beta4 params
    beta_params = parameters["beta_params"] | {"pij": pij, "n_respondents": pij.shape[1], "n_items": pij.shape[0]}

    # fit
    beta4_model = claire.fit_beta4(**beta_params)

    # metrics
    data_metrics = claire.calculate_metrics(data_results, beta4_model, claire._X[i], claire._Y[i])

    # contents
    dir_contents = [
        (
            "metrics",
            (
                "metrics" + ext_type,
                data_metrics.sort_values("abilities", ascending=False),
            ),
            (None),
        ),
        (
            "pij",
            ("pij_true" + ext_type, pij),
            ("pij_pred" + ext_type, pd.DataFrame(claire.b4.pij, columns=pij.columns)),
        ),
        (
            "params",
            (
                "abilities" + ext_type,
                pd.DataFrame(claire.b4.abilities, index=pij.columns, columns=["abilities"]),
            ),
            (
                "diff_disc" + ext_type,
                pd.DataFrame(
                    {
                        "difficulty": claire.b4.difficulties,
                        "discrimination": claire.b4.discriminations,
                    }
                ),
            ),
        ),
        ("labels", ("labels" + ext_type, data_results), (None)),
    ]
    #  save
    claire.save_results(i, dir_contents)

# %%
def process_k_random(k_random, init_generate, stop_generate, path_result, _X, _Y, config, data_random, parameters):
    which_k_random = "n_random_model: [ {} ]".format(k_random + 1)
    print(title_part_n1 + which_k_random + title_part_n3)
    if number_random_models != 1:
        path_result_k_random = path_result / Path(f"random_n{k_random+1}")
        if not os.path.exists(path_result_k_random):
            os.makedirs(path_result_k_random)
    with concurrent.futures.ThreadPoolExecutor(max_workers=16) as executor:
        process_func = partial(process_file, k_random, path_result_k_random, _X, _Y, config, data_random, parameters)
        executor.map(process_func, config.file_names)

# %% [markdown]
# ## Running for all clusterings dataset

# %%
_X, _Y = {}, {}
for i in config.file_names:
    _X[i] = data_all[i].drop("labels", axis=1).values
    _Y[i] = data_all[i]["labels"].values

# %%
# select if it is random include simulation
if parameters["include_random_model"]:
    number_random_models = len(np.unique(list(config.models_name_dataset.values())[0]))
else:
    number_random_models = 1
path_result = Path(config.dir_result)

# %%
init_generate = parameters["experiments"]["rp_init"]

if parameters["experiments"]["rp_final"] == "max":
    stop_generate = number_random_models
else:
    stop_generate = parameters["experiments"]["rp_final"]

# %%
data_random = {}
for i in tqdm(config.file_names):
    data_random[i] = pd.DataFrame()
    if len(np.unique(_Y[i])) == 1:
        n_clusters = np.random.randint(1, 10)
    else:
        n_clusters = len(np.unique(_Y[i]))
    for k_random in tqdm(range(init_generate + 1, stop_generate + 1)):
        np.random.seed(k_random)
        data_random[i][f"random_model_n{k_random}"] = np.random.randint(0, n_clusters, _X[i].shape[0])
# Out:
#   0%|                                                                                                                                                                                        | 0/9 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:00<00:00, 6346.49it/s]
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:00<00:00, 6561.51it/s]
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:00<00:00, 6899.17it/s]
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:00<00:00, 6318.35it/s]
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:00<00:00, 6422.85it/s]
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:00<00:00, 6747.28it/s]
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:00<00:00, 6804.20it/s]
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:00<00:00, 6595.71it/s]
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:00<00:00, 6002.89it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 138.55it/s]

# %%
del config.params["optics"]
for k_random in tqdm(range(init_generate, stop_generate)):
    process_k_random(k_random, init_generate, stop_generate, path_result, _X, _Y, config, data_random, parameters)
# Out:
#   0%|                                                                                                                                                                                       | 0/35 [00:00<?, ?it/s]
# -------------------------------------------------------------
# n_random_model: [ 1 ]
# -------------------------------------------------------------
#
#
# -------------------------------------------------------------
# dataset: [ iris ]
# -------------------------------------------------------------
#
#
# -------------------------------------------------------------
# dataset: [ breast_cancer ]
# -------------------------------------------------------------
#
#
# -------------------------------------------------------------
# dataset: [ wine ]
# -------------------------------------------------------------
#
#
# -------------------------------------------------------------
# dataset: [ blobs ]
# -------------------------------------------------------------
#
#
# -------------------------------------------------------------
# dataset: [ varied ]
# -------------------------------------------------------------
#
#
# -------------------------------------------------------------
# dataset: [ noisy_moons ]
# -------------------------------------------------------------
#
#
# -------------------------------------------------------------
# dataset: [ no_structure ]
# -------------------------------------------------------------
#
#
# -------------------------------------------------------------
# dataset: [ aniso ]
# -------------------------------------------------------------
#
#
# -------------------------------------------------------------
# dataset: [ noisy_circles ]
# -------------------------------------------------------------
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 150 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 178 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 150 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 150 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 150 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 150 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 178 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 150 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 150 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 150 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 569 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 178 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 1000 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 178 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 178 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
#
#   0%|                                                                                                                                                                                      | 0/150 [00:00<?, ?it/s]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 178 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
#
#   1%|█▏                                                                                                                                                                            | 1/150 [00:15<38:17, 15.42s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
#
#   1%|██▎                                                                                                                                                                           | 2/150 [00:32<40:06, 16.26s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 178 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
#
#   2%|███▍                                                                                                                                                                          | 3/150 [00:48<39:23, 16.08s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
#
#   3%|████▋                                                                                                                                                                         | 4/150 [01:02<36:57, 15.19s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 178 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
#
#   3%|█████▊                                                                                                                                                                        | 5/150 [01:11<31:56, 13.22s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
#
#   4%|██████▉                                                                                                                                                                       | 6/150 [01:21<28:57, 12.06s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:273: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 1000 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
#
#   5%|████████                                                                                                                                                                      | 7/150 [01:42<35:25, 14.86s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:273: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#
#   5%|█████████▎                                                                                                                                                                    | 8/150 [02:06<42:23, 17.91s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:273: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#
#   6%|██████████▍                                                                                                                                                                   | 9/150 [02:15<35:08, 14.95s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:273: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:273: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 500 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
#
#   7%|███████████▌                                                                                                                                                                 | 10/150 [02:17<26:00, 11.15s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:273: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#
#   7%|████████████▋                                                                                                                                                                | 11/150 [02:24<22:51,  9.87s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 1000 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
# /root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:273: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#
#   8%|█████████████▊                                                                                                                                                               | 12/150 [02:27<17:36,  7.66s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:273: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#
#   9%|██████████████▉                                                                                                                                                              | 13/150 [02:28<13:19,  5.84s/it]
#   9%|████████████████▏                                                                                                                                                            | 14/150 [02:29<09:23,  4.14s/it]
#  10%|█████████████████▎                                                                                                                                                           | 15/150 [02:29<06:43,  2.99s/it]
#  11%|██████████████████▍                                                                                                                                                          | 16/150 [02:30<05:20,  2.39s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:273: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#
#  11%|███████████████████▌                                                                                                                                                         | 17/150 [02:31<04:29,  2.03s/it]
#  12%|████████████████████▊                                                                                                                                                        | 18/150 [02:32<03:45,  1.71s/it]
#  13%|█████████████████████▉                                                                                                                                                       | 19/150 [02:33<02:55,  1.34s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:273: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#
#  13%|███████████████████████                                                                                                                                                      | 20/150 [02:34<02:52,  1.33s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:273: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#
#  14%|████████████████████████▏                                                                                                                                                    | 21/150 [02:35<02:29,  1.16s/it]
#  15%|█████████████████████████▎                                                                                                                                                   | 22/150 [02:35<02:00,  1.06it/s]
#  15%|██████████████████████████▌                                                                                                                                                  | 23/150 [02:35<01:35,  1.34it/s]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:273: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#
#  16%|███████████████████████████▋                                                                                                                                                 | 24/150 [02:38<02:36,  1.24s/it]
# ...
#
#
#
#   1%|█                                                                                                                                                                           | 3/500 [00:25<1:09:27,  8.39s/it]
#
#
#
#
#
#   0%|▋                                                                                                                                                                           | 2/500 [00:16<1:08:14,  8.22s/it]
#  35%|███████████████████████████████████████████████████████████▉                                                                                                                 | 52/150 [03:54<03:49,  2.34s/it]
#
#   7%|████████████▋                                                                                                                                                                | 13/178 [00:39<07:22,  2.68s/it]
#
#
#   1%|█▍                                                                                                                                                                          | 4/500 [00:32<1:02:18,  7.54s/it]
#  35%|█████████████████████████████████████████████████████████████▏                                                                                                               | 53/150 [03:57<03:57,  2.45s/it]
#
#   8%|█████████████▌                                                                                                                                                               | 14/178 [00:42<07:00,  2.57s/it]
#  36%|██████████████████████████████████████████████████████████████▎                                                                                                              | 54/150 [04:00<04:08,  2.59s/it]
#
#   8%|██████████████▌                                                                                                                                                              | 15/178 [00:45<07:09,  2.63s/it]
#
#
#
#
#
#
#   1%|█                                                                                                                                                                             | 3/500 [00:20<55:42,  6.73s/it]
#
#
#
#
#   1%|█                                                                                                                                                                           | 3/500 [00:23<1:01:58,  7.48s/it]
#
#
#
#   1%|█▍                                                                                                                                                                          | 4/500 [00:31<1:03:04,  7.63s/it]
#  37%|███████████████████████████████████████████████████████████████▍                                                                                                             | 55/150 [04:01<03:09,  2.00s/it]
#
#
#
#
#
#   1%|█                                                                                                                                                                           | 3/500 [00:23<1:01:47,  7.46s/it]
#
#   9%|███████████████▌                                                                                                                                                             | 16/178 [00:45<05:44,  2.12s/it]
#
#
#   1%|█▋                                                                                                                                                                            | 5/500 [00:38<56:00,  6.79s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 1000 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
#
#  37%|████████████████████████████████████████████████████████████████▌                                                                                                            | 56/150 [04:01<02:30,  1.60s/it]
#
#  10%|████████████████▌                                                                                                                                                            | 17/178 [00:52<09:21,  3.49s/it]
#  38%|█████████████████████████████████████████████████████████████████▋                                                                                                           | 57/150 [04:09<05:11,  3.35s/it]
#
#
#
#
#
#
#   1%|█▍                                                                                                                                                                          | 4/500 [00:35<1:21:49,  9.90s/it]
#  39%|██████████████████████████████████████████████████████████████████▉                                                                                                          | 58/150 [04:15<06:37,  4.32s/it]
#
#  10%|█████████████████▍                                                                                                                                                           | 18/178 [01:00<12:42,  4.76s/it]
#
#
#
#
#   1%|█▍                                                                                                                                                                          | 4/500 [00:41<1:37:31, 11.80s/it]
#
#
#
#   1%|█▋                                                                                                                                                                          | 5/500 [00:50<1:36:21, 11.68s/it]
#
#
#
#
#
#   1%|█▍                                                                                                                                                                          | 4/500 [00:42<1:39:01, 11.98s/it]
#  39%|████████████████████████████████████████████████████████████████████                                                                                                         | 59/150 [04:20<06:51,  4.52s/it]
#
#  11%|██████████████████▍                                                                                                                                                          | 19/178 [01:05<12:54,  4.87s/it]
#
#
#   1%|██                                                                                                                                                                          | 6/500 [00:57<1:31:07, 11.07s/it]
#  40%|█████████████████████████████████████████████████████████████████████▏                                                                                                       | 60/150 [04:21<05:07,  3.41s/it]/root/.cache/pypoetry/virtualenvs/aaai-claire-clustering-1i6KO2qc-py3.10/lib/python3.10/site-packages/tslearn/utils/utils.py:88: UserWarning: 2-Dimensional data passed. Assuming these are 1000 1-dimensional timeseries
#   warnings.warn('2-Dimensional data passed. Assuming these are '
#
#
#  11%|███████████████████▍                                                                                                                                                         | 20/178 [01:06<10:01,  3.81s/it]
#  41%|██████████████████████████████████████████████████████████████████████▎                                                                                                      | 61/150 [04:24<04:41,  3.17s/it]
#
#
#
#
#
#
#   1%|█▋                                                                                                                                                                          | 5/500 [00:44<1:19:08,  9.59s/it]
#
#
#
#   1%|██                                                                                                                                                                          | 6/500 [00:55<1:17:39,  9.43s/it]
#
#
#
#
#   1%|█▋                                                                                                                                                                          | 5/500 [00:47<1:19:39,  9.65s/it]
#
#  12%|████████████████████▍                                                                                                                                                        | 21/178 [01:10<09:29,  3.63s/it]
#
#
#
#
#
#   1%|█▋                                                                                                                                                                          | 5/500 [00:48<1:20:42,  9.78s/it]
#  41%|███████████████████████████████████████████████████████████████████████▌                                                                                                     | 62/150 [04:26<04:09,  2.83s/it]
#
#
#   1%|██▍                                                                                                                                                                         | 7/500 [01:03<1:16:18,  9.29s/it]
#
#  12%|█████████████████████▍                                                                                                                                                       | 22/178 [01:14<10:07,  3.90s/it]
#  42%|████████████████████████████████████████████████████████████████████████▋                                                                                                    | 63/150 [04:30<04:33,  3.14s/it]
#  43%|█████████████████████████████████████████████████████████████████████████▊                                                                                                   | 64/150 [04:32<04:14,  2.95s/it]
#
#  13%|██████████████████████▎                                                                                                                                                      | 23/178 [01:17<09:03,  3.51s/it]
#
#
#
#
#
#
#   1%|██                                                                                                                                                                          | 6/500 [00:53<1:16:57,  9.35s/it]
#
#
#
#   1%|██▍                                                                                                                                                                         | 7/500 [01:05<1:18:33,  9.56s/it]
#
#
#
#
#   1%|██                                                                                                                                                                          | 6/500 [00:57<1:19:41,  9.68s/it]
#
#  13%|███████████████████████▎                                                                                                                                                     | 24/178 [01:20<08:45,  3.42s/it]
#  43%|██████████████████████████████████████████████████████████████████████████▉                                                                                                  | 65/150 [04:35<04:20,  3.06s/it]
#
#
#
#
#
#   1%|██                                                                                                                                                                          | 6/500 [00:58<1:21:15,  9.87s/it]
#
#
#   2%|██▊                                                                                                                                                                         | 8/500 [01:12<1:16:49,  9.37s/it]
#
#  14%|████████████████████████▎                                                                                                                                                    | 25/178 [01:22<07:51,  3.08s/it]
#  44%|████████████████████████████████████████████████████████████████████████████                                                                                                 | 66/150 [04:38<03:58,  2.84s/it]
#  45%|█████████████████████████████████████████████████████████████████████████████▎                                                                                               | 67/150 [04:39<03:25,  2.48s/it]
#
#  15%|█████████████████████████▎                                                                                                                                                   | 26/178 [01:24<07:00,  2.76s/it]
#
#
#
#
#
#
#   1%|██▍                                                                                                                                                                         | 7/500 [01:03<1:18:01,  9.50s/it]
#
#
#
#   2%|██▊                                                                                                                                                                         | 8/500 [01:14<1:17:06,  9.40s/it]
#  45%|██████████████████████████████████████████████████████████████████████████████▍                                                                                              | 68/150 [04:44<04:02,  2.95s/it]
#
#
#
#
#   1%|██▍                                                                                                                                                                         | 7/500 [01:06<1:18:12,  9.52s/it]
#
#  15%|██████████████████████████▏                                                                                                                                                  | 27/178 [01:28<08:02,  3.20s/it]
#
#
#   2%|███                                                                                                                                                                         | 9/500 [01:21<1:14:04,  9.05s/it]
#
#
#
#
#
#   1%|██▍                                                                                                                                                                         | 7/500 [01:07<1:18:14,  9.52s/it]
#  46%|███████████████████████████████████████████████████████████████████████████████▌                                                                                             | 69/150 [04:45<03:29,  2.59s/it]
#
#  16%|███████████████████████████▏                                                                                                                                                 | 28/178 [01:31<07:11,  2.88s/it]
#  47%|████████████████████████████████████████████████████████████████████████████████▋                                                                                            | 70/150 [04:47<02:58,  2.23s/it]
#
#  16%|████████████████████████████▏                                                                                                                                                | 29/178 [01:31<05:36,  2.26s/it]
#
#
#
#
#
#
#   2%|██▊                                                                                                                                                                         | 8/500 [01:07<1:04:53,  7.91s/it]
#  47%|█████████████████████████████████████████████████████████████████████████████████▉                                                                                           | 71/150 [04:47<02:21,  1.79s/it]
#
#
#
#   2%|███                                                                                                                                                                         | 9/500 [01:18<1:03:21,  7.74s/it]
#
#
#
#
#   2%|██▊                                                                                                                                                                         | 8/500 [01:10<1:03:44,  7.77s/it]
#
#
#   2%|███▍                                                                                                                                                                       | 10/500 [01:24<1:00:23,  7.39s/it]
#
#  17%|█████████████████████████████▏                                                                                                                                               | 30/178 [01:32<04:34,  1.85s/it]
#
#
#
#
#
#   2%|██▊                                                                                                                                                                         | 8/500 [01:10<1:02:09,  7.58s/it]
#  48%|███████████████████████████████████████████████████████████████████████████████████                                                                                          | 72/150 [04:48<01:55,  1.49s/it]
