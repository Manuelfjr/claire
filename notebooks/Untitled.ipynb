# %%
import concurrent.futures
import os
import math
from pathlib import Path
import sys
PROJECT_DIR = Path.cwd().parent
sys.path.append(str(PROJECT_DIR))
from utils import config
import pandas as pd


import concurrent.futures
import os
from pathlib import Path

class ParallelExecutor:
    def __init__(self, max_workers=None):
        self.max_workers = max_workers
import concurrent.futures
import os
from pathlib import Path

class ParallelExecutor:
    def __init__(self, max_workers=None):
        self.max_workers = max_workers

    def execute(self, function, *parameters):
        with concurrent.futures.ThreadPoolExecutor(max_workers=self.max_workers) as executor:
            results = list(executor.map(function, *parameters))
        return results

def complex_math_calculation(file_path):
    # Replace this with your actual processing logic
    with open(file_path, 'r') as file:
        content = file.read()
    return len(content)

PROJECT_DIR = Path.cwd().parent
file_path_data = {
    "file1": PROJECT_DIR / "data" / "file1" / "file1.csv",
    "file2": PROJECT_DIR / "data" / "file2" / "file2.csv",
    # Add more files as needed
}

pe = ParallelExecutor(os.cpu_count())
results = pe.execute(complex_math_calculation, file_path_data.values())

print(results)

    def execute(self, function, *parameters):
        with concurrent.futures.ThreadPoolExecutor(max_workers=self.max_workers) as executor:
            results = list(executor.map(function, *parameters))
        return results

def complex_math_calculation(file_path):
    return pd.read_csv(file_path)

# %%
file_path_data = {
    i: PROJECT_DIR / "data" / i / f"{i}.csv" for i in config.file_names
}

# %%
# %%time
pe = ParallelExecutor(os.cpu_count())
results = pe.execute(complex_math_calculation, file_path_data.values())
# Out:
# CPU times: user 73.3 ms, sys: 8.77 ms, total: 82.1 ms
# Wall time: 60 ms

# %%
# %%time
result = []
for i in file_path_data.values():
    result.append(complex_math_calculation(i))
# Out:
# CPU times: user 10.8 ms, sys: 71 µs, total: 10.9 ms
# Wall time: 10.7 ms

# %%
results
# Out:
# [            0         1         2         3  labels
#  0   -0.900681  1.019004 -1.340227 -1.315444       0
#  1   -1.143017 -0.131979 -1.340227 -1.315444       0
#  2   -1.385353  0.328414 -1.397064 -1.315444       0
#  3   -1.506521  0.098217 -1.283389 -1.315444       0
#  4   -1.021849  1.249201 -1.340227 -1.315444       0
#  ..        ...       ...       ...       ...     ...
#  145  1.038005 -0.131979  0.819596  1.448832       2
#  146  0.553333 -1.282963  0.705921  0.922303       2
#  147  0.795669 -0.131979  0.819596  1.053935       2
#  148  0.432165  0.788808  0.933271  1.448832       2
#  149  0.068662 -0.131979  0.762758  0.790671       2
#
#  [150 rows x 5 columns],
#              0         1         2         3         4         5         6  \
#  0    1.518613 -0.562250  0.232053 -1.169593  1.913905  0.808997  1.034819
#  1    0.246290 -0.499413 -0.827996 -2.490847  0.018145  0.568648  0.733629
#  2    0.196879  0.021231  1.109334 -0.268738  0.088358  0.808997  1.215533
#  3    1.691550 -0.346811  0.487926 -0.809251  0.930918  2.491446  1.466525
#  4    0.295700  0.227694  1.840403  0.451946  1.281985  0.808997  0.663351
#  ..        ...       ...       ...       ...       ...       ...       ...
#  173  0.876275  2.974543  0.305159  0.301803 -0.332922 -0.985614 -1.424900
#  174  0.493343  1.412609  0.414820  1.052516  0.158572 -0.793334 -1.284344
#  175  0.332758  1.744744 -0.389355  0.151661  1.422412 -1.129824 -1.344582
#  4    0.220556 -0.313395  0.613179  0.729259 -0.868353 -0.397100       0
#  ..        ...       ...       ...       ...       ...       ...     ...
#  564  0.378365 -0.273318  0.664512  1.629151 -1.360158 -0.709091       0
#  565 -0.691230 -0.394820  0.236573  0.733827 -0.531855 -0.973978       0
#  566 -0.809587  0.350735  0.326767  0.414069 -1.104549 -0.318409       0
#  567  1.430427  3.904848  3.197605  2.289985  1.919083  2.219635       0
#  568 -1.859019 -1.207552 -1.305831 -1.745063 -0.048138 -0.751207       1
#
#  [569 rows x 31 columns],
#              0         1  labels
#  0    1.688541 -1.625101       2
#  1    1.006940 -0.765019       2
#  2   -0.654824  1.180603       1
#  3    2.015136 -2.191073       2
#  4   -0.821097 -0.199450       0
#  ..        ...       ...     ...
#  495 -0.417964 -0.594933       0
#  496  1.744886 -1.573820       2
#  497 -0.376732  0.645942       1
#  498 -1.356465  1.126261       0
#  499  1.291974 -0.970177       2
#
#  [500 rows x 3 columns],
#              0         1  labels
#  0   -1.578117 -1.292868       2
#  1    0.702799  1.193823       0
#  2    0.785453  1.191428       0
#  3    0.675761 -0.040024       1
#  4    0.848431  0.223061       1
#  ..        ...       ...     ...
#  495  0.759530 -0.051960       1
#  496  0.801515  0.214023       1
#  497  0.726605  1.026708       0
#  498  0.908538  1.140056       0
#  499 -1.192645 -1.092598       2
#
#  [500 rows x 3 columns],
#              0         1  labels
#  0    1.291612  0.563365       2
#  1    1.075674  0.620076       2
#  2   -0.275439  0.686819       1
#  3    1.347618  0.427187       2
#  4   -1.294033 -1.615424       0
#  ..        ...       ...     ...
#  495 -0.968751 -1.522088       0
#  496  1.347215  0.645382       2
#  497 -0.118350 -0.079789       1
#  498 -1.232124 -0.605086       0
#  499  1.213641  0.705831       2
#
#  [500 rows x 3 columns],
#              0         1  labels
#  0    0.196678 -1.370113       1
#  1    1.045971 -1.430571       1
#  2    0.402540  0.332134       0
#  3   -0.055348  1.105940       0
#  4    1.693464 -0.164915       1
#  ..        ...       ...     ...
#  495 -0.494511 -0.129685       1
#  496  0.385427  0.519926       0
#  497  1.281112 -1.172085       1
#  498 -0.463354 -0.399554       1
#  499  1.658855 -0.226576       1
#
#  [500 rows x 3 columns],
#              0         1  labels
#  0   -1.187336  1.367611       0
#  1    0.713381  0.111090       1
#  2    0.647881  0.667368       1
#  3    0.139348 -0.857370       1
#  4    0.531352 -0.977394       1
#  ..        ...       ...     ...
#  495 -0.138872  0.914791       1
#  496  0.170808 -1.869478       0
#  497 -1.990915  0.461786       0
#  498  0.623776  1.606703       0
#  499 -0.663987 -1.760523       0
#
#  [500 rows x 3 columns],
#              0         1  labels
#  0   -0.210050  1.409400     NaN
#  1   -0.214012 -0.156631     NaN
#  2   -1.212581  0.540434     NaN
#  3   -1.192547 -0.674688     NaN
#  4    0.635337 -0.686931     NaN
#  ..        ...       ...     ...
#  995  0.364034  0.451206     NaN
#  996  1.018292  0.064856     NaN
#  997 -1.511701  0.542512     NaN
#  998 -1.204662  1.100684     NaN
#  999 -1.233777  1.537598     NaN
#
#  [1000 rows x 3 columns]]
